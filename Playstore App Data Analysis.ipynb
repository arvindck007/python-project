# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Arvind C\Downloads\Apps_data+(1).csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
rating_missing_values = df.Rating.isnull().sum()
    
    
if rating_missing_values > 0:
    df = df.dropna(subset = ['Rating'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9367 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9367 non-null   object
#  1   Category        9367 non-null   object
#  2   Rating          9367 non-null   float64
#  3   Reviews         9367 non-null   object
#  4   Size            9367 non-null   object
#  5   Installs        9367 non-null   object
#  6   Type            9367 non-null   object
#  7   Price           9367 non-null   object
#  8   Content Rating  9366 non-null   object
#  9   Genres          9367 non-null   object
#  10  Last Updated    9367 non-null   object
#  11  Current Ver     9363 non-null   object
#  12  Android Ver     9364 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
df.nunique()
# Out:
# App               8197
# Category            34
# Rating              40
# Reviews           5993
# Size               415
# Installs            20
# Type                 3
# Price               74
# Content Rating       6
# Genres             116
# Last Updated      1301
# Current Ver       2639
# Android Ver         31
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8893 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8893 non-null   object
#  1   Category        8893 non-null   object
#  2   Rating          8893 non-null   float64
#  3   Reviews         8893 non-null   object
#  4   Size            8893 non-null   object
#  5   Installs        8893 non-null   object
#  6   Type            8893 non-null   object
#  7   Price           8893 non-null   object
#  8   Content Rating  8892 non-null   object
#  9   Genres          8893 non-null   object
#  10  Last Updated    8893 non-null   object
#  11  Current Ver     8889 non-null   object
#  12  Android Ver     8890 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 972.7+ KB

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,  3. ,
#         1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,  1.8,
#         2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df[df['Rating']==19. ]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df = df[df['Rating'] != 19.]

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8892 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8892 non-null   object
#  1   Category        8892 non-null   object
#  2   Rating          8892 non-null   float64
#  3   Reviews         8892 non-null   object
#  4   Size            8892 non-null   object
#  5   Installs        8892 non-null   object
#  6   Type            8892 non-null   object
#  7   Price           8892 non-null   object
#  8   Content Rating  8892 non-null   object
#  9   Genres          8892 non-null   object
#  10  Last Updated    8892 non-null   object
#  11  Current Ver     8888 non-null   object
#  12  Android Ver     8890 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 972.6+ KB

# %%
df['Rating_category'] = df['Rating'].apply(lambda x : 'High' if x > 3.5 else 'Low')

# %%
df["Installs"].min()
# Out:
# '1+'

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df['Reviews_log']=df['Reviews'].apply(lambda x : np.log1p(x) if x > 0 else 0)

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M',
#        '11M', '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M',
#        '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M',
#        '5.7M', '8.6M', '2.4M', '27M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
df['Size']=df.Size.replace('Varies with device',np.nan)
df['Size']=df.Size.str.replace('M',"000")
df['Size']=df.Size.str.replace("K","")
df['Size']=df.Size.str.replace("k","")
df['Size']=df.Size.replace("1,000+","1000")
df['Size']=df['Size'].astype(float)

# %%
df['Size'].dtype
# Out:
# dtype('float64')

# %%
df['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+00, 2.50e+04, 2.80e+00, 5.60e+00,
#        2.90e+04, 3.30e+04, 3.10e+00, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+00, 5.50e+00, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+00, 2.30e+04, 6.00e+00, 6.10e+00, 4.60e+00,
#        9.20e+00, 5.20e+00, 1.10e+04, 2.40e+04,      nan, 9.40e+00,
#        1.50e+04, 1.00e+04, 1.20e+00, 2.60e+04, 8.00e+00, 7.90e+00,
#        5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02, 3.60e+00,
#        5.70e+00, 8.60e+00, 2.40e+00, 2.70e+04, 2.50e+00, 7.00e+00,
#        1.60e+04, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+04,
#        3.20e+04, 5.40e+00, 1.80e+04, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+04, 9.00e+00, 6.70e+00, 3.00e+04, 2.60e+00,
#        7.10e+00, 2.20e+04, 6.40e+00, 3.20e+00, 8.20e+00, 4.90e+00,
#        9.50e+00, 5.00e+00, 5.90e+00, 1.30e+04, 7.30e+04, 6.80e+00,
#        3.50e+00, 4.00e+00, 2.30e+00, 2.10e+00, 4.20e+04, 9.10e+00,
# ...

# %%
df["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
df["Installs"]=df.Installs.str.replace("+","")
df["Installs"]=df.Installs.str.replace(",","")
df["Installs"]=df['Installs'].astype(float)
df["Installs"].dtype
# Out:
# C:\Users\Arvind C\AppData\Local\Temp\ipykernel_23644\2027132740.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Installs"]=df.Installs.str.replace("+","")
# dtype('float64')

# %%
df["Installs"].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 1.e+02, 5.e+02, 1.e+01,
#        5.e+00, 5.e+01, 1.e+00])

# %%
df["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
df['Price']=df.Price.str.replace("$","")
df['Price']=df['Price'].astype(float)
df['Price'].dtype
# Out:
# C:\Users\Arvind C\AppData\Local\Temp\ipykernel_23644\2878811243.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df.Price.str.replace("$","")
# dtype('float64')

# %%
df["Price"].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Last Updated']=pd.to_datetime(df['Last Updated'])

# %%
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10834   2017-06-18
# 10836   2017-07-25
# 10837   2018-07-06
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 8892, dtype: datetime64[ns]

# %%
df['Reviews'].unique()
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307], dtype=int64)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8892 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   App              8892 non-null   object
#  1   Category         8892 non-null   object
#  2   Rating           8892 non-null   float64
#  3   Reviews          8892 non-null   int64
#  4   Size             7424 non-null   float64
#  5   Installs         8892 non-null   float64
#  6   Type             8892 non-null   object
#  7   Price            8892 non-null   float64
#  8   Content Rating   8892 non-null   object
#  9   Genres           8892 non-null   object
#  10  Last Updated     8892 non-null   datetime64[ns]
#  11  Current Ver      8888 non-null   object
#  12  Android Ver      8890 non-null   object
#  13  Rating_category  8892 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(8)
# memory usage: 1.0+ MB

# %%
df.corr()
# Out:
# C:\Users\Arvind C\AppData\Local\Temp\ipykernel_23644\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068732  0.080156  0.050886 -0.022355
# Reviews   0.068732  1.000000  0.236161  0.633429 -0.009558
# Size      0.080156  0.236161  1.000000  0.167012 -0.026697
# Installs  0.050886  0.633429  0.167012  1.000000 -0.011329
# Price    -0.022355 -0.009558 -0.026697 -0.011329  1.000000

# %%
df.cov()
# Out:
# C:\Users\Arvind C\AppData\Local\Temp\ipykernel_26304\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                 Rating       Reviews          Size      Installs         Price
# Rating    2.728774e-01  1.043033e+05  1.097398e+03  2.296016e+06 -1.890523e-01
# Reviews   1.043033e+05  8.439326e+12  1.025505e+10  1.589443e+14 -4.495365e+05
# Size      1.097398e+03  1.025505e+10  6.202339e+08  1.925951e+11 -1.177402e+04
# Installs  2.296016e+06  1.589443e+14  1.925951e+11  7.460813e+15 -1.584255e+07
# Price    -1.890523e-01 -4.495365e+05 -1.177402e+04 -1.584255e+07  2.620948e+02

# %%
sns.countplot(x = 'Rating_category',data = df)
# Out:
# <Axes: xlabel='Rating_category', ylabel='count'>

# %%
category_counts=df['Category'].value_counts()
plt.figure(figsize=(10,6))
sns.countplot(y='Category',data=df,order=category_counts.index)
plt.title("distribution of category")
plt.xlabel("no of downloads")
plt.ylabel("categories")
# Out:
# Text(0, 0.5, 'categories')

# %%
print(df['Rating'].describe())
plt.figure(figsize=(10,6))
sns.histplot(df['Rating'],bins=30,kde=True)
plt.show()
sns.pairplot(df[['Rating', 'Category', 'Reviews', 'Size']], hue='Category', diag_kind='kde')
plt.show()
# Out:
# count    8892.000000
# mean        4.187877
# std         0.522377
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Reviews'])
plt.title('Boxplot of Reviews')
plt.xlabel('Reviews')
plt.show()

# %%
# Determine the top 20 most frequent app names
top_20_apps = df['App'].value_counts().head(20)

# Create a countplot for the top 20 app names
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.countplot(x='App', data=df[df['App'].isin(top_20_apps.index)], palette='Set2')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
type_of_app=df['Type'].value_counts()
plt.figure(figsize=(6,8))
plt.pie(type_of_app,labels=type_of_app.index,autopct='%1.1f%%')
plt.title("Distribution of App Types")
plt.show()

# %%
df1.isna().sum()
# Out:
# App                0
# Category           0
# Rating             0
# Reviews            0
# Size               0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        4
# Android Ver        2
# Rating_category    0
# Reviews_log        0
# dtype: int64

# %%
columns_to_drop = ['App', 'Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
df1 = df1.drop(columns = columns_to_drop, axis = 1)

# %%
df1.head()
# Out:
#          Category   Reviews  Size  Installs  Type  Price Content Rating  \
# 0  ART_AND_DESIGN     159.0  19.0     10000  Free    0.0       Everyone
# 1  ART_AND_DESIGN     967.0  14.0    500000  Free    0.0       Everyone
# 2  ART_AND_DESIGN   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  ART_AND_DESIGN  215644.0  25.0  50000000  Free    0.0           Teen
# 4  ART_AND_DESIGN     967.0   2.8    100000  Free    0.0       Everyone
#
#   Rating_category  Reviews_log
# 0            High     5.075174
# 1            High     6.875232
# 2            High    11.379520
# 3            High    12.281389
# 4            High     6.875232

# %%
df1['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['Category_encoded'] = label_encoder.fit_transform(df1['Category'])

# %%
df1.head()
# Out:
#          Category   Reviews  Size  Installs  Type  Price Content Rating  \
# 0  ART_AND_DESIGN     159.0  19.0     10000  Free    0.0       Everyone
# 1  ART_AND_DESIGN     967.0  14.0    500000  Free    0.0       Everyone
# 2  ART_AND_DESIGN   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  ART_AND_DESIGN  215644.0  25.0  50000000  Free    0.0           Teen
# 4  ART_AND_DESIGN     967.0   2.8    100000  Free    0.0       Everyone
#
#   Rating_category  Reviews_log  Category_encoded
# 0            High     5.075174                 0
# 1            High     6.875232                 0
# 2            High    11.379520                 0
# 3            High    12.281389                 0
# 4            High     6.875232                 0

# %%
df1['Content Rating_encoded'] = label_encoder.fit_transform(df1['Content Rating'])

# %%
df1.head()
# Out:
#          Category   Reviews  Size  Installs  Type  Price Content Rating  \
# 0  ART_AND_DESIGN     159.0  19.0     10000  Free    0.0       Everyone
# 1  ART_AND_DESIGN     967.0  14.0    500000  Free    0.0       Everyone
# 2  ART_AND_DESIGN   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  ART_AND_DESIGN  215644.0  25.0  50000000  Free    0.0           Teen
# 4  ART_AND_DESIGN     967.0   2.8    100000  Free    0.0       Everyone
#
#   Rating_category  Reviews_log  Category_encoded  Content Rating_encoded
# 0            High     5.075174                 0                       1
# 1            High     6.875232                 0                       1
# 2            High    11.379520                 0                       1
# 3            High    12.281389                 0                       4
# 4            High     6.875232                 0                       1

# %%
df1['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df1['Rating_category'] = label_encoder.fit_transform(df1['Rating_category'])

# %%
df1['Type'] = label_encoder.fit_transform(df1['Type'])

# %%
df1.head()
# Out:
#          Category   Reviews  Size  Installs  Type  Price Content Rating  \
# 0  ART_AND_DESIGN     159.0  19.0     10000     0    0.0       Everyone
# 1  ART_AND_DESIGN     967.0  14.0    500000     0    0.0       Everyone
# 2  ART_AND_DESIGN   87510.0   8.7   5000000     0    0.0       Everyone
# 3  ART_AND_DESIGN  215644.0  25.0  50000000     0    0.0           Teen
# 4  ART_AND_DESIGN     967.0   2.8    100000     0    0.0       Everyone
#
#    Rating_category  Reviews_log  Category_encoded  Content Rating_encoded
# 0                0     5.075174                 0                       1
# 1                0     6.875232                 0                       1
# 2                0    11.379520                 0                       1
# 3                0    12.281389                 0                       4
# 4                0     6.875232                 0                       1

# %%
df1 = df1.drop(['Category', 'Content Rating'], axis=1)

# %%
df1.head()
# Out:
#     Reviews  Size  Installs  Type  Price  Rating_category  Reviews_log  \
# 0     159.0  19.0     10000     0    0.0                0     5.075174
# 1     967.0  14.0    500000     0    0.0                0     6.875232
# 2   87510.0   8.7   5000000     0    0.0                0    11.379520
# 3  215644.0  25.0  50000000     0    0.0                0    12.281389
# 4     967.0   2.8    100000     0    0.0                0     6.875232
#
#    Category_encoded  Content Rating_encoded
# 0                 0                       1
# 1                 0                       1
# 2                 0                       1
# 3                 0                       4
# 4                 0                       1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7729 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Reviews                 7729 non-null   float64
#  1   Size                    7729 non-null   float64
#  2   Installs                7729 non-null   int64
#  3   Type                    7729 non-null   int32
#  4   Price                   7729 non-null   float64
#  5   Rating_category         7729 non-null   int32
#  6   Reviews_log             7729 non-null   float64
#  7   Category_encoded        7729 non-null   int32
#  8   Content Rating_encoded  7729 non-null   int32
# dtypes: float64(4), int32(4), int64(1)
# memory usage: 483.1 KB

# %%
df1.isnull().sum()
# Out:
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# Rating_category           0
# Reviews_log               0
# Category_encoded          0
# Content Rating_encoded    0
# dtype: int64

# %%
X = df1.drop('Rating_category', axis=1)  # Independent features
y = df1['Rating_category']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (5410, 8)

# %%
X_test.shape
# Out:
# (2319, 8)

# %%
y_train.shape
# Out:
# (5410,)

# %%
y_test.shape
# Out:
# (2319,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled.shape
# Out:
# (5410, 8)

# %% [markdown]
# ### honey bee project

# %% [markdown]
# 1) Import required libraries and read the dataset.

# %%
df = pd.read_csv(r"C:\Users\Arvind C\Downloads\honeyproduction.csv")

# %% [markdown]
# 2) Check the first few samples, shape, info of the data and try to familiarize yourself with different features.¶

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
years = df.groupby('year').size()/len(df)*100
plt.figure(figsize=(6,8))
plt.pie(years, labels=years.index, autopct='%1.1f%%')
plt.title('Percentage Distribution of Data in Each Year')
plt.show()

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
plt.figure(figsize = (6,8))
sns.distplot(df['priceperlb'])
plt.title("Distribution of the variable (price per lb) using displot")
plt.show()
# Out:
# C:\Users\Arvind C\AppData\Local\Temp\ipykernel_14148\2408990351.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['priceperlb'])

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your findings.

# %%
plt.figure(figsize=(6,8))
plt.scatter(df['numcol'], df['prodvalue'],color = "green")
plt.xlabel('Number of Colonies')
plt.ylabel('Production Value')
plt.title('Relationship between Number of Colonies and Production Value using a Scatter Plot.')
plt.show()

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable

# %%
plt.figure(figsize=(9,9))
sns.boxplot(x='year', y='prodvalue', data=df)
plt.title('Relationship between Year and Prodvalue')
plt.show()

# %% [markdown]
# Q7) Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences.¶

# %%
sns.pairplot(df, vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year'], hue='year',palette='viridis')

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
data_subset = df[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]
corr_matrix = data_subset.corr()
sns.heatmap(corr_matrix, annot=True,cmap = "BuPu")
plt.title("Correlation Matrix")
plt.show()
